# %% [markdown]
# # VAST Challenge 2024 | Mini-Challenge 3

# %% [markdown]
# Enlace al [Enunciado del mini-reto 3](https://vast-challenge.github.io/2024/MC3.html)

# %% [markdown]
# ## Tareas y preguntas

# %% [markdown]
# ### 1. Dinámica de estructuras corporativas

# %% [markdown]
# > FishEye analysts want to better visualize changes in corporate structures over time. Create a visual analytics approach that analysts can use to highlight temporal patterns and changes in corporate structures. Examine the most active people and businesses using visual analytics.

# %% [markdown]
# ### 2. Transaccion típicas y atípicas

# %% [markdown]
# >   Using your visualizations, find and display examples of typical and atypical business transactions (e.g., mergers, acquisitions, etc.). Can you infer the motivations behind changes in their activity?

# %% [markdown]
# ### 3. Pertenencia e influencia sobre compañías

# %% [markdown]
# > Develop a visual approach to examine inferences. Infer how the influence of a company changes through time. Can you infer ownership or influence that a network may have?

# %% [markdown]
# ### 4. Redes con _SouthSeafood Express Corp_

# %% [markdown]
# > Identify the network associated with SouthSeafood Express Corp and visualize how this network and competing businesses change as a result of their illegal fishing behavior. Which companies benefited from SouthSeafood Express Corp legal troubles? Are there other suspicious transactions that may be related to illegal fishing? Provide visual evidence for your conclusions.

# %% [markdown]
# ## Carga de datos

# %% [markdown]
# ### uncompressed file

# %%
import json
import pandas as pd

# %%
json_file = './MC3/mc3.json'

# %%
# open json file
with open(json_path) as json_file:
    data = json.load(json_file)

# %%
# Convert list of dictionaries to DataFrame
df_nodes = pd.DataFrame(data['nodes'])
df_links = pd.DataFrame(data['links'])

# %%
df_nodes.head()
# Out:
#                           type      country                 ProductServices  \
# 0  Entity.Organization.Company      Uziland                         Unknown
# 1  Entity.Organization.Company     Mawalara  Furniture and home accessories
# 2  Entity.Organization.Company     Uzifrica                   Food products
# 3  Entity.Organization.Company  Islavaragon                         Unknown
# 4  Entity.Organization.Company      Oceanus                         Unknown
#
#      PointOfContact                    HeadOfOrg        founding_date  \
# 0     Rebecca Lewis          Émilie-Susan Benoit  1954-04-24T00:00:00
# 1     Michael Lopez               Honoré Lemoine  2009-06-12T00:00:00
# 2  Steven Robertson                  Jules Labbé  2029-12-15T00:00:00
# 3     Anthony Wyatt           Dr. Víctor Hurtado  1972-02-16T00:00:00
# 4     Tracy Schmidt  Jacques Le Roux de Leclercq  1954-04-06T00:00:00
#
#     revenue                                   TradeDescription  \
# 0   5994.73                                            Unknown
# 1  71766.67  Abbott-Gomez is a leading manufacturer and sup...
# 2      0.00  Abbott-Harrison is a leading manufacturer of h...
# 3      0.00                                            Unknown
# 4   4746.67                                            Unknown
#
#            _last_edited_by    _last_edited_date          _date_added  \
# 0  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 1  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 2  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 3  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 4  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
#
#                          _raw_source        _algorithm  \
# 0  Existing Corporate Structure Data  Automatic Import
# 1  Existing Corporate Structure Data  Automatic Import
# 2  Existing Corporate Structure Data  Automatic Import
# 3  Existing Corporate Structure Data  Automatic Import
# 4  Existing Corporate Structure Data  Automatic Import
#
#                             id  dob
# 0  Abbott, Mcbride and Edwards  NaN
# 1                 Abbott-Gomez  NaN
# 2              Abbott-Harrison  NaN
# 3                Abbott-Ibarra  NaN
# 4              Abbott-Sullivan  NaN

# %%
# Entidades -> partir en personas y otra en organizaciones
df_nodes['type'].value_counts()
# Out:
# type
# Entity.Person                           50356
# Entity.Organization.Company              7927
# Entity.Person.CEO                        1293
# Entity.Organization.FishingCompany        600
# Entity.Organization.LogisticsCompany      311
# Entity.Organization.FinancialCompany       23
# Entity.Organization.NewsCompany             5
# Entity.Organization.NGO                     5
# Name: count, dtype: int64

# %%
# create anothe dataframe for Entity.Person
Person_df = df_nodes[df_nodes['type'] == 'Entity.Person']

# %%
# number of entries in Entity.Person
Person_df.keys()
# Out:
# Index(['type', 'country', 'ProductServices', 'PointOfContact', 'HeadOfOrg',
#        'founding_date', 'revenue', 'TradeDescription', '_last_edited_by',
#        '_last_edited_date', '_date_added', '_raw_source', '_algorithm', 'id',
#        'dob'],
#       dtype='object')

# %% [markdown]
# ### Links

# %%
df_links['type'].unique()
# Out:
# array(['Event.Owns.Shareholdership', 'Event.Owns.BeneficialOwnership',
#        'Event.WorksFor', 'Relationship.FamilyRelationship'], dtype=object)

# %%
df_links[df_links['type'] == 'Event.Owns.Shareholdership']
# Out:
#                 start_date                        type  \
# 0      2016-10-29T00:00:00  Event.Owns.Shareholdership
# 1      2035-06-03T00:00:00  Event.Owns.Shareholdership
# 2      2028-11-20T00:00:00  Event.Owns.Shareholdership
# 3      2024-09-04T00:00:00  Event.Owns.Shareholdership
# 4      2034-11-12T00:00:00  Event.Owns.Shareholdership
# ...                    ...                         ...
# 75753  2030-09-18T00:00:00  Event.Owns.Shareholdership
# 75763  2034-10-09T00:00:00  Event.Owns.Shareholdership
# 75768  2031-01-10T00:00:00  Event.Owns.Shareholdership
# 75772  2016-04-24T00:00:00  Event.Owns.Shareholdership
# 75802  2026-10-11T00:00:00  Event.Owns.Shareholdership
#
#                _last_edited_by    _last_edited_date          _date_added  \
# 0      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 1               Niklaus Oberon  2035-07-15T00:00:00  2035-07-15T00:00:00
# 2      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 3      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 4      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# ...                        ...                  ...                  ...
# 75753  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75763  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75768  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75772  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75802  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
#
#                                   _raw_source        _algorithm  \
# 0           Existing Corporate Structure Data  Automatic Import
# 1      Oceanus Corporations Monthly - Jun '35      Manual Entry
# 2           Existing Corporate Structure Data  Automatic Import
# 3           Existing Corporate Structure Data  Automatic Import
# 4           Existing Corporate Structure Data  Automatic Import
# ...                                       ...               ...
# 75753       Existing Corporate Structure Data  Automatic Import
# 75763       Existing Corporate Structure Data  Automatic Import
# 75768       Existing Corporate Structure Data  Automatic Import
# 75772       Existing Corporate Structure Data  Automatic Import
# 75802       Existing Corporate Structure Data  Automatic Import
#
#                    source                                 target  key end_date
# 0               Avery Inc            Allen, Nichols and Thompson    0      NaN
# 1            Berger-Hayes               Jensen, Morris and Downs    0      NaN
# 2            Bowers Group                            Barnett Inc    0      NaN
# 3             Bowman-Howe                            Bennett Ltd    0      NaN
# 4           Boyd and Sons          Armstrong, Bennett and Deleon    0      NaN
# ...                   ...                                    ...  ...      ...
# 75753     Akira Hernandez  PregolyaDredge Logistics Incorporated    2      NaN
# 75763  Lily Baker-Mercier             Irtysh Creek Logistics Inc    1      NaN
# 75768    Samuel Hernandez                 6. America Transit Plc    1      NaN
# 75772          Isla Davis          EastOcean Carriers Ges.m.b.H.    1      NaN
# 75802  Robert Mccarthy II                            Raymond LLC    1      NaN
#
# [39378 rows x 11 columns]

# %%
# show only those links that are of type 'Event.WorksFor'
df_links[df_links['type'] == 'Event.WorksFor']
# Out:
#                 start_date            type          _last_edited_by  \
# 337             2015-12-21  Event.WorksFor  Pelagia Alethea Mordoch
# 377             2026-07-01  Event.WorksFor  Pelagia Alethea Mordoch
# 605             2030-03-31  Event.WorksFor  Pelagia Alethea Mordoch
# 671             2017-01-23  Event.WorksFor  Pelagia Alethea Mordoch
# 2736            2025-10-10  Event.WorksFor  Pelagia Alethea Mordoch
# ...                    ...             ...                      ...
# 75811  2028-05-21T00:00:00  Event.WorksFor  Pelagia Alethea Mordoch
# 75813  2032-08-04T00:00:00  Event.WorksFor  Pelagia Alethea Mordoch
# 75814  2031-10-04T00:00:00  Event.WorksFor  Pelagia Alethea Mordoch
# 75815  2026-08-23T00:00:00  Event.WorksFor  Pelagia Alethea Mordoch
# 75816  2026-12-28T00:00:00  Event.WorksFor  Pelagia Alethea Mordoch
#
#          _last_edited_date          _date_added  \
# 337    2035-01-01T00:00:00  2035-01-01T00:00:00
# 377    2035-01-01T00:00:00  2035-01-01T00:00:00
# 605    2035-01-01T00:00:00  2035-01-01T00:00:00
# 671    2035-01-01T00:00:00  2035-01-01T00:00:00
# 2736   2035-01-01T00:00:00  2035-01-01T00:00:00
# ...                    ...                  ...
# 75811  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75813  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75814  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75815  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75816  2035-01-01T00:00:00  2035-01-01T00:00:00
#
#                              _raw_source        _algorithm  \
# 337    Existing Corporate Structure Data  Automatic Import
# 377    Existing Corporate Structure Data  Automatic Import
# 605    Existing Corporate Structure Data  Automatic Import
# 671    Existing Corporate Structure Data  Automatic Import
# 2736   Existing Corporate Structure Data  Automatic Import
# ...                                  ...               ...
# 75811  Existing Corporate Structure Data  Automatic Import
# 75813  Existing Corporate Structure Data  Automatic Import
# 75814  Existing Corporate Structure Data  Automatic Import
# 75815  Existing Corporate Structure Data  Automatic Import
# 75816  Existing Corporate Structure Data  Automatic Import
#
#                    source                   target  key end_date
# 337          Laura Newman           Wright-Bennett    1      NaN
# 377    Matthew Valenzuela  Sims, Allen and Griffin    1      NaN
# 605           Tara Taylor           Mccoy and Sons    1      NaN
# 671         Maurice Moran              Daniels LLC    1      NaN
# 2736         Tyler Foster            Morris-Taylor    1      NaN
# ...                   ...                      ...  ...      ...
# 75811    Braydon Mccarthy              Raymond LLC    0      NaN
# 75813       Lauren Wagner            Hartman Group    0      NaN
# 75814         Emily Yates        Bailey-Mccullough    0      NaN
# 75815     Patrick Mueller               Vargas Ltd    0      NaN
# 75816         Mandy Ramos               Conrad Ltd    0      NaN
#
# [14817 rows x 11 columns]

# %%
# show only those links that are of type 'Event.Owns.Shareholdership'
df_links[df_links['type'] == 'Event.Owns.Shareholdership']
# Out:
#                 start_date                        type  \
# 0      2016-10-29T00:00:00  Event.Owns.Shareholdership
# 1      2035-06-03T00:00:00  Event.Owns.Shareholdership
# 2      2028-11-20T00:00:00  Event.Owns.Shareholdership
# 3      2024-09-04T00:00:00  Event.Owns.Shareholdership
# 4      2034-11-12T00:00:00  Event.Owns.Shareholdership
# ...                    ...                         ...
# 75753  2030-09-18T00:00:00  Event.Owns.Shareholdership
# 75763  2034-10-09T00:00:00  Event.Owns.Shareholdership
# 75768  2031-01-10T00:00:00  Event.Owns.Shareholdership
# 75772  2016-04-24T00:00:00  Event.Owns.Shareholdership
# 75802  2026-10-11T00:00:00  Event.Owns.Shareholdership
#
#                _last_edited_by    _last_edited_date          _date_added  \
# 0      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 1               Niklaus Oberon  2035-07-15T00:00:00  2035-07-15T00:00:00
# 2      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 3      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 4      Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# ...                        ...                  ...                  ...
# 75753  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75763  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75768  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75772  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 75802  Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
#
#                                   _raw_source        _algorithm  \
# 0           Existing Corporate Structure Data  Automatic Import
# 1      Oceanus Corporations Monthly - Jun '35      Manual Entry
# 2           Existing Corporate Structure Data  Automatic Import
# 3           Existing Corporate Structure Data  Automatic Import
# 4           Existing Corporate Structure Data  Automatic Import
# ...                                       ...               ...
# 75753       Existing Corporate Structure Data  Automatic Import
# 75763       Existing Corporate Structure Data  Automatic Import
# 75768       Existing Corporate Structure Data  Automatic Import
# 75772       Existing Corporate Structure Data  Automatic Import
# 75802       Existing Corporate Structure Data  Automatic Import
#
#                    source                                 target  key end_date
# 0               Avery Inc            Allen, Nichols and Thompson    0      NaN
# 1            Berger-Hayes               Jensen, Morris and Downs    0      NaN
# 2            Bowers Group                            Barnett Inc    0      NaN
# 3             Bowman-Howe                            Bennett Ltd    0      NaN
# 4           Boyd and Sons          Armstrong, Bennett and Deleon    0      NaN
# ...                   ...                                    ...  ...      ...
# 75753     Akira Hernandez  PregolyaDredge Logistics Incorporated    2      NaN
# 75763  Lily Baker-Mercier             Irtysh Creek Logistics Inc    1      NaN
# 75768    Samuel Hernandez                 6. America Transit Plc    1      NaN
# 75772          Isla Davis          EastOcean Carriers Ges.m.b.H.    1      NaN
# 75802  Robert Mccarthy II                            Raymond LLC    1      NaN
#
# [39378 rows x 11 columns]

# %%
# Relaciones entre personas y entidades
df_links['type'].value_counts()
# Out:
# type
# Event.Owns.Shareholdership         39378
# Event.Owns.BeneficialOwnership     21531
# Event.WorksFor                     14817
# Relationship.FamilyRelationship       91
# Name: count, dtype: int64

# %%
WorksFor_df = df_links[df_links['type'] == 'Relation.WorksFor']

# %%
WorksFor_df.shape
# Out:
# (0, 11)

# %%
WorksFor_df.head()
# Out:
# Empty DataFrame
# Columns: [start_date, type, _last_edited_by, _last_edited_date, _date_added, _raw_source, _algorithm, source, target, key, end_date]
# Index: []

# %%
# show in df_links only entries where type is Event.WorksFor
WorksFor_df = df_links[df_links['type'] == 'Relation.WorksFor']
WorksFor_df.head()
# Out:
# Empty DataFrame
# Columns: [start_date, type, _last_edited_by, _last_edited_date, _date_added, _raw_source, _algorithm, source, target, key, end_date]
# Index: []

# %% [markdown]
# En algún lado está (supongo en los links) un start y un end date.
