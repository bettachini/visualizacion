# %%
import pandas as pd

# %%
import json

import chardet

# First, read the file in binary mode
with open('mc3.json', 'rb') as file:
    raw_data = file.read()

# Detect encoding
encoding = chardet.detect(raw_data)['encoding']

# Now, open the file with the detected encoding
with open('mc3.json', 'r', encoding=encoding) as file:
    data = json.load(file)

# %%
# data.keys() # dict_keys(['directed', 'multigraph', 'graph', 'nodes', 'links'])
# len(data['nodes']) # 60520
# len(data['links']) # 75817
data['nodes']

# %%
# Convert list of dictionaries to DataFrame
df_nodes = pd.DataFrame(data['nodes'])
df_links = pd.DataFrame(data['links'])

# %%
# df.head(2)
df_nodes.groupby('type').head(1)
# Out:
#                                       type   country
# 0              Entity.Organization.Company   Uziland  \
# 11    Entity.Organization.LogisticsCompany  Lumakari
# 12      Entity.Organization.FishingCompany  Valtalmo
# 91    Entity.Organization.FinancialCompany   Oceanus
# 4968       Entity.Organization.NewsCompany   Oceanus
# 8679               Entity.Organization.NGO   Oceanus
# 8684                         Entity.Person   Arvaros
# 9012                     Entity.Person.CEO  Mawalara
#
#                                         ProductServices    PointOfContact
# 0                                               Unknown     Rebecca Lewis  \
# 11    Operates tramp vessels for transporting variou...  Calvin Rodriguez
# 12                                       Seafood frozen     Scott Merritt
# 91    Covers financing casino expansions, hotel expa...    Justin Aguilar
# 4968  Publication and printing of newspapers and mag...      Lauren Gomez
# ...

# %%
df_nodes['type'].value_counts()
# Out:
# type
# Entity.Person                           50356
# Entity.Organization.Company              7927
# Entity.Person.CEO                        1293
# Entity.Organization.FishingCompany        600
# Entity.Organization.LogisticsCompany      311
# Entity.Organization.FinancialCompany       23
# Entity.Organization.NewsCompany             5
# Entity.Organization.NGO                     5
# Name: count, dtype: int64

# %%
Organization_Company = df_nodes[df_nodes['type'] == 'Entity.Organization.Company'].dropna(axis=1, how='all')
Organization_FishingCompany = df_nodes[df_nodes['type'] == 'Entity.Organization.FishingCompany'].dropna(axis=1, how='all')
Organization_LogisticsCompany = df_nodes[df_nodes['type'] == 'Entity.Organization.LogisticsCompany'].dropna(axis=1, how='all')
Organization_FinancialCompany = df_nodes[df_nodes['type'] == 'Entity.Organization.FinancialCompany'].dropna(axis=1, how='all')
Organization_NewsCompany = df_nodes[df_nodes['type'] == 'Entity.Organization.NewsCompany'].dropna(axis=1, how='all')
Organization_NGO = df_nodes[df_nodes['type'] == 'Entity.Organization.NGO'].dropna(axis=1, how='all')
Person = df_nodes[df_nodes['type'] == 'Entity.Person'].dropna(axis=1, how='all')
Person_CEO = df_nodes[df_nodes['type'] == 'Entity.Person.CEO'].dropna(axis=1, how='all')

# %%
df_links.groupby('type').head(2)
# Out:
#                start_date                             type
# 0     2016-10-29T00:00:00       Event.Owns.Shareholdership  \
# 1     2035-06-03T00:00:00       Event.Owns.Shareholdership
# 335   2018-05-10T00:00:00   Event.Owns.BeneficialOwnership
# 337            2015-12-21                   Event.WorksFor
# 338   2013-11-30T00:00:00   Event.Owns.BeneficialOwnership
# 377            2026-07-01                   Event.WorksFor
# 5369                  NaN  Relationship.FamilyRelationship
# 5370                  NaN  Relationship.FamilyRelationship
#
#               _last_edited_by    _last_edited_date          _date_added
# 0     Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00  \
# 1              Niklaus Oberon  2035-07-15T00:00:00  2035-07-15T00:00:00
# 335   Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# 337   Pelagia Alethea Mordoch  2035-01-01T00:00:00  2035-01-01T00:00:00
# ...

# %%
df_links['type'].value_counts()
# Out:
# type
# Event.Owns.Shareholdership         39378
# Event.Owns.BeneficialOwnership     21531
# Event.WorksFor                     14817
# Relationship.FamilyRelationship       91
# Name: count, dtype: int64

# %%
Event_Owns_Shareholdership = df_links[df_links['type'] == 'Event.Owns.Shareholdership'].dropna(axis=1, how='all')
Event_Owns_BeneficialOwnership = df_links[df_links['type'] == 'Event.Owns.BeneficialOwnership'].dropna(axis=1, how='all')
Event_WorksFor = df_links[df_links['type'] == 'Event.WorksFor'].dropna(axis=1, how='all')
Relationship_FamilyRelationship = df_links[df_links['type'] == 'Relationship.FamilyRelationship'].dropna(axis=1, how='all')

# %% [markdown]
# ## describe all df_nodes

# %%
Organization_Company.describe(include='all')
# Out:
#                                type  country ProductServices  PointOfContact
# count                          7927     7927            7927            7909  \
# unique                            1       79            2710            7661
# top     Entity.Organization.Company  Oceanus         Unknown  Emily Williams
# freq                           7927     2646            4740               6
# mean                            NaN      NaN             NaN             NaN
# std                             NaN      NaN             NaN             NaN
# min                             NaN      NaN             NaN             NaN
# 25%                             NaN      NaN             NaN             NaN
# 50%                             NaN      NaN             NaN             NaN
# 75%                             NaN      NaN             NaN             NaN
# max                             NaN      NaN             NaN             NaN
#
# ...

# %%
#   ['revenue'].
Organization_Company.sort_values(by='revenue', ascending=False).head(20)
# Out:
#                              type    country
# 755   Entity.Organization.Company    Arvaros  \
# 7100  Entity.Organization.Company    Arvaros
# 5912  Entity.Organization.Company    Oceanus
# 8391  Entity.Organization.Company    Arvaros
# 6759  Entity.Organization.Company    Oceanus
# 8612  Entity.Organization.Company    Arvaros
# 390   Entity.Organization.Company   Mawandia
# 3550  Entity.Organization.Company   Mawandia
# 4182  Entity.Organization.Company    Arvaros
# 167   Entity.Organization.Company    Oceanus
# 7407  Entity.Organization.Company  Naraliket
# 3928  Entity.Organization.Company    Oceanus
# 6530  Entity.Organization.Company   Uzifrica
# 576   Entity.Organization.Company   Mawandia
# 7992  Entity.Organization.Company   Mawandia
# 6745  Entity.Organization.Company    Arvaros
# 194   Entity.Organization.Company   Lumakari
# 3527  Entity.Organization.Company   Faraluna
# 2748  Entity.Organization.Company   Lumakari
# 4805  Entity.Organization.Company   Mawandia
#
# ...

# %%
Organization_FishingCompany.describe(include='all')
# Out:
#                                       type  country
# count                                  600      600  \
# unique                                   1       46
# top     Entity.Organization.FishingCompany  Oceanus
# freq                                   600      207
# mean                                   NaN      NaN
# std                                    NaN      NaN
# min                                    NaN      NaN
# 25%                                    NaN      NaN
# 50%                                    NaN      NaN
# 75%                                    NaN      NaN
# max                                    NaN      NaN
#
#                   ProductServices PointOfContact      HeadOfOrg
# count                         600            599            599  \
# unique                        253            588            599
# top     Fish and seafood products    Danny Brown  Gregory Hobbs
# freq                           70              5              1
# ...

# %%
Organization_FinancialCompany.describe(include='all')
# Out:
#                                         type  country  ProductServices
# count                                     23       23               23  \
# unique                                     1       11               22
# top     Entity.Organization.FinancialCompany  Oceanus  Holding company
# freq                                      23        6                2
# mean                                     NaN      NaN              NaN
# std                                      NaN      NaN              NaN
# min                                      NaN      NaN              NaN
# 25%                                      NaN      NaN              NaN
# 50%                                      NaN      NaN              NaN
# 75%                                      NaN      NaN              NaN
# max                                      NaN      NaN              NaN
#
#         PointOfContact    HeadOfOrg        founding_date       revenue
# ...

# %%
Organization_LogisticsCompany.describe(include='all')
# Out:
#                                         type  country
# count                                    311      311  \
# unique                                     1       31
# top     Entity.Organization.LogisticsCompany  Oceanus
# freq                                     311      149
# mean                                     NaN      NaN
# std                                      NaN      NaN
# min                                      NaN      NaN
# 25%                                      NaN      NaN
# 50%                                      NaN      NaN
# 75%                                      NaN      NaN
# max                                      NaN      NaN
#
#                                           ProductServices PointOfContact
# count                                                 311            305  \
# unique                                                258            304
# top     Freight trucking and other related transportat...    Mariah Carr
# ...

# %%
Organization_NewsCompany#.describe(include='all')
# Out:
#                                  type  country
# 4968  Entity.Organization.NewsCompany  Oceanus  \
# 8675  Entity.Organization.NewsCompany  Oceanus
# 8676  Entity.Organization.NewsCompany  Oceanus
# 8677  Entity.Organization.NewsCompany  Oceanus
# 8678  Entity.Organization.NewsCompany  Oceanus
#
#                                         ProductServices    PointOfContact
# 4968  Publication and printing of newspapers and mag...      Lauren Gomez  \
# 8675  Publication of daily newspaper, website, and o...      Cynthia Hull
# 8676  Publication of daily newspaper, website, and o...    Lauren Schmidt
# 8677  Publication of daily newspaper, website, and o...  Alexis Carpenter
# 8678  Publication of daily newspaper, website, and o...        James Bell
#
#              HeadOfOrg        founding_date   revenue
# 4968    Kathleen Perez  1984-01-16T00:00:00  12496.67  \
# 8675   Jessica Simpson  1975-04-08T00:00:00      0.00
# 8676  Patricia Bennett  2001-05-17T00:00:00      0.00
# ...

# %%
Organization_NGO#.describe(include='all')
# Out:
#                          type  country
# 8679  Entity.Organization.NGO  Oceanus  \
# 8680  Entity.Organization.NGO  Oceanus
# 8681  Entity.Organization.NGO  Oceanus
# 8682  Entity.Organization.NGO  Oceanus
# 8683  Entity.Organization.NGO  Oceanus
#
#                                         ProductServices    PointOfContact
# 8679  Advocates for marine life and ecological conse...       Mallory Roy  \
# 8680  Advocates for marine life and ecological conse...         Tara King
# 8681  Provides high-quality, publicly accessible dat...    Gabrielle Carr
# 8682  Provides updates on policy changes, legal issu...       Lori Benson
# 8683  Provides news, updates, and resources for cora...  Kristina Collins
#
#                 HeadOfOrg        founding_date  revenue
# 8679          Susan Hines  2029-08-12T00:00:00      0.0  \
# 8680     Thomas Gallagher  1999-07-04T00:00:00      0.0
# 8681          Gina Garcia  2019-02-02T00:00:00      0.0
# ...

# %%
Person[Person['_last_edited_by']!='Pelagia Alethea Mordoch']
# Out:
#                 type      country _last_edited_by    _last_edited_date
# 60003  Entity.Person  Coralmarica  Niklaus Oberon  2035-02-15T00:00:00  \
# 60004  Entity.Person      Arvaros  Niklaus Oberon  2035-02-15T00:00:00
# 60007  Entity.Person   Novarctica  Niklaus Oberon  2035-02-15T00:00:00
# 60008  Entity.Person    Kilivaria  Niklaus Oberon  2035-02-15T00:00:00
# 60009  Entity.Person    Isliandor  Niklaus Oberon  2035-02-15T00:00:00
# ...              ...          ...             ...                  ...
# 60413  Entity.Person     Mawandia  Niklaus Oberon  2035-12-15T00:00:00
# 60414  Entity.Person  Isla Solmar  Niklaus Oberon  2035-12-15T00:00:00
# 60417  Entity.Person      Oceanus  Niklaus Oberon  2035-12-15T00:00:00
# 60482  Entity.Person      Oceanus  Niklaus Oberon  2035-06-15T00:00:00
# 60483  Entity.Person      Oceanus  Niklaus Oberon  2035-12-15T00:00:00
#
#                _date_added                             _raw_source
# ...

# %%
Person.describe(include='all')
# Out:
#                  type   country          _last_edited_by    _last_edited_date
# count           50356     50356                    50356                50356  \
# unique              1        86                        2                   12
# top     Entity.Person  Mawalara  Pelagia Alethea Mordoch  2035-01-01T00:00:00
# freq            50356      3568                    50178                50178
#
#                 _date_added                        _raw_source
# count                 50356                              50356  \
# unique                   12                                 12
# top     2035-01-01T00:00:00  Existing Corporate Structure Data
# freq                  50178                              50178
#
#               _algorithm            id                  dob
# count              50356         50356                50356
# unique                 2         50356                14925
# top     Automatic Import  Laura Newman  1971-10-27T00:00:00
# ...

# %%
Person_CEO.describe(include='all')
# Out:
#                      type  country          _last_edited_by
# count                1293     1293                     1293  \
# unique                  1       81                        2
# top     Entity.Person.CEO  Oceanus  Pelagia Alethea Mordoch
# freq                 1293       48                     1177
#
#           _last_edited_date          _date_added
# count                  1293                 1293  \
# unique                   12                   12
# top     2035-01-01T00:00:00  2035-01-01T00:00:00
# freq                   1177                 1177
#
#                               _raw_source        _algorithm               id
# count                                1293              1293             1293  \
# unique                                 12                 2             1293
# top     Existing Corporate Structure Data  Automatic Import  Brian Robertson
# freq                                 1177              1177                1
#
# ...

# %% [markdown]
# ## describe df_links all

# %%
Event_Owns_BeneficialOwnership.describe(include='all')
# Out:
#                  start_date                            type
# count                 21531                           21531  \
# unique                 9205                               1
# top     2035-07-13T00:00:00  Event.Owns.BeneficialOwnership
# freq                     25                           21531
# mean                    NaN                             NaN
# std                     NaN                             NaN
# min                     NaN                             NaN
# 25%                     NaN                             NaN
# 50%                     NaN                             NaN
# 75%                     NaN                             NaN
# max                     NaN                             NaN
#
#                 _last_edited_by    _last_edited_date          _date_added
# count                     21531                21531                21531  \
# unique                        2                   13                   13
# ...

# %%
Event_Owns_Shareholdership.describe(include='all')
# Out:
#                  start_date                        type
# count                 39378                       39378  \
# unique                10676                           1
# top     2034-12-22T00:00:00  Event.Owns.Shareholdership
# freq                     22                       39378
# mean                    NaN                         NaN
# std                     NaN                         NaN
# min                     NaN                         NaN
# 25%                     NaN                         NaN
# 50%                     NaN                         NaN
# 75%                     NaN                         NaN
# max                     NaN                         NaN
#
#                 _last_edited_by    _last_edited_date          _date_added
# count                     39378                39378                39378  \
# unique                        2                   13                   13
# ...

# %%
Event_Owns_Shareholdership.describe(include='all')
# Out:
#                  start_date                        type
# count                 39378                       39378  \
# unique                10676                           1
# top     2034-12-22T00:00:00  Event.Owns.Shareholdership
# freq                     22                       39378
# mean                    NaN                         NaN
# std                     NaN                         NaN
# min                     NaN                         NaN
# 25%                     NaN                         NaN
# 50%                     NaN                         NaN
# 75%                     NaN                         NaN
# max                     NaN                         NaN
#
#                 _last_edited_by    _last_edited_date          _date_added
# count                     39378                39378                39378  \
# unique                        2                   13                   13
# ...

# %%
Relationship_FamilyRelationship.describe(include='all')
# Out:
#                  start_date                             type
# count                     1                               91  \
# unique                    1                                1
# top     2028-05-21T00:00:00  Relationship.FamilyRelationship
# freq                      1                               91
# mean                    NaN                              NaN
# std                     NaN                              NaN
# min                     NaN                              NaN
# 25%                     NaN                              NaN
# 50%                     NaN                              NaN
# 75%                     NaN                              NaN
# max                     NaN                              NaN
#
#                 _last_edited_by    _last_edited_date          _date_added
# count                        91                   91                   91  \
# unique                        1                    1                    1
# ...
